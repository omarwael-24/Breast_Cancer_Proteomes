# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import yaml as ym 
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer

# %%
with open("../config.yaml","r",encoding="utf-8") as file:
    config=ym.safe_load(file)

# %%
df1=pd.read_csv(config['paths']['raw_data'][0])
df1.head()
# Out:
#   RefSeq_accession_number gene_symbol           gene_name  AO-A12D.01TCGA  \
# 0               NP_958782        PLEC   plectin isoform 1        1.096131
# 1               NP_958785         NaN  plectin isoform 1g        1.111370
# 2               NP_958786        PLEC  plectin isoform 1a        1.111370
# 3               NP_000436         NaN  plectin isoform 1c        1.107561
# 4               NP_958781         NaN  plectin isoform 1e        1.115180
#
#    C8-A131.01TCGA  AO-A12B.01TCGA  BH-A18Q.02TCGA  C8-A130.02TCGA  \
# 0        2.609943       -0.659828        0.195341       -0.494060
# 1        2.650422       -0.648742        0.215413       -0.503899
# 2        2.650422       -0.654285        0.215413       -0.500619
# 3        2.646374       -0.632113        0.205377       -0.510459
# 4        2.646374       -0.640428        0.215413       -0.503899
#
#    C8-A138.03TCGA  E2-A154.03TCGA  ...  AO-A12B.34TCGA  A2-A0SW.35TCGA  \
# 0        2.765081        0.862659  ...       -0.963904       -0.487772
# 1        2.779709        0.870186  ...       -0.938210       -0.487772
# 2        2.779709        0.870186  ...       -0.943919       -0.487772
# 3        2.797995        0.866423  ...       -0.935355       -0.487772
# 4        2.787023        0.870186  ...       -0.935355       -0.503853
#
#    AO-A0JL.35TCGA  BH-A0BV.35TCGA  A2-A0YM.36TCGA  BH-A0C7.36TCGA  \
# 0        -0.10668       -0.065838        0.655850       -0.552212
# 1        -0.10668       -0.055893        0.658143       -0.547749
# 2        -0.10668       -0.065838        0.655850       -0.552212
# 3        -0.10668       -0.055893        0.655850       -0.552212
# 4        -0.10668       -0.062523        0.651264       -0.556675
#
#    A2-A0SX.36TCGA  263d3f-I.CPTAC  blcdb9-I.CPTAC  c4155b-C.CPTAC
# 0       -0.398560        0.598585       -0.191285        0.566975
# 1       -0.392601        0.606697       -0.183918        0.578702
# 2       -0.392601        0.603993       -0.186022        0.576747
# 3       -0.392601        0.603993       -0.186022        0.576747
# 4       -0.395581        0.603993       -0.167079        0.576747
#
# [5 rows x 86 columns]

# %%
df1.transpose().head()
# Out:
#                                      0                   1      \
# RefSeq_accession_number          NP_958782           NP_958785
# gene_symbol                           PLEC                 NaN
# gene_name                plectin isoform 1  plectin isoform 1g
# AO-A12D.01TCGA                    1.096131             1.11137
# C8-A131.01TCGA                    2.609943            2.650422
#
#                                       2                   3      \
# RefSeq_accession_number           NP_958786           NP_000436
# gene_symbol                            PLEC                 NaN
# gene_name                plectin isoform 1a  plectin isoform 1c
# AO-A12D.01TCGA                      1.11137            1.107561
# C8-A131.01TCGA                     2.650422            2.646374
#
#                                       4                   5      \
# RefSeq_accession_number           NP_958781           NP_958780
# gene_symbol                             NaN                PLEC
# gene_name                plectin isoform 1e  plectin isoform 1f
# AO-A12D.01TCGA                      1.11518            1.107561
# C8-A131.01TCGA                     2.646374            2.646374
#
#                                       6                   7          8      \
# RefSeq_accession_number           NP_958783           NP_958784  NP_112598
# gene_symbol                            PLEC                 NaN        NaN
# gene_name                plectin isoform 1d  plectin isoform 1b  epiplakin
# AO-A12D.01TCGA                      1.11137             1.11137   -1.51739
# C8-A131.01TCGA                     2.650422            2.650422   3.909313
#
#                                                                      9      \
# RefSeq_accession_number                                          NP_001611
# gene_symbol                                                          AHNAK
# gene_name                neuroblast differentiation-associated protein ...
# AO-A12D.01TCGA                                                    0.482754
# C8-A131.01TCGA                                                   -1.045294
#
#                          ...                              12543  \
# RefSeq_accession_number  ...                       NP_001193600
# gene_symbol              ...                                NaN
# gene_name                ...  protein RIC-3 isoform c precursor
# AO-A12D.01TCGA           ...                                NaN
# C8-A131.01TCGA           ...                                NaN
#
#                                                                      12544  \
# RefSeq_accession_number                                          NP_061134
# gene_symbol                                                          BATF3
# gene_name                basic leucine zipper transcriptional factor AT...
# AO-A12D.01TCGA                                                         NaN
# C8-A131.01TCGA                                                         NaN
#
#                                                      12545  \
# RefSeq_accession_number                          NP_932347
# gene_symbol                                          SCML4
# gene_name                sex comb on midleg-like protein 4
# AO-A12D.01TCGA                                         NaN
# C8-A131.01TCGA                                         NaN
#
#                                                                      12546  \
# RefSeq_accession_number                                          NP_003593
# gene_symbol                                                          FKBP6
# gene_name                peptidyl-prolyl cis-trans isomerase FKBP6 isof...
# AO-A12D.01TCGA                                                   -0.340163
# C8-A131.01TCGA                                                    3.451902
#
#                                                     12547  \
# RefSeq_accession_number                         NP_997203
# gene_symbol                                        OTUD6A
# gene_name                OTU domain-containing protein 6A
# AO-A12D.01TCGA                                        NaN
# C8-A131.01TCGA                                        NaN
#
#                                             12548  \
# RefSeq_accession_number              NP_001191293
# gene_symbol                                   NaN
# gene_name                protein FAM24B precursor
# AO-A12D.01TCGA                                NaN
# C8-A131.01TCGA                                NaN
#
#                                                             12549  \
# RefSeq_accession_number                                 NP_775791
# gene_symbol                                                   NaN
# gene_name                putative uncharacterized protein C9orf62
# AO-A12D.01TCGA                                                NaN
# C8-A131.01TCGA                                                NaN
#
#                                                                   12550  \
# RefSeq_accession_number                                       NP_004065
# gene_symbol                                                       COX8A
# gene_name                cytochrome c oxidase subunit 8A, mitochondrial
# AO-A12D.01TCGA                                                      NaN
# C8-A131.01TCGA                                                      NaN
#
#                                                              12551  \
# RefSeq_accession_number                                  NP_068752
# gene_symbol                                                   MIIP
# gene_name                migration and invasion-inhibitory protein
# AO-A12D.01TCGA                                           -0.633517
# C8-A131.01TCGA                                            4.840325
#
#                                                     12552
# RefSeq_accession_number                         NP_219494
# gene_symbol                                      KIAA1737
# gene_name                uncharacterized protein KIAA1737
# AO-A12D.01TCGA                                  12.666488
# C8-A131.01TCGA                                   0.140736
#
# [5 rows x 12553 columns]
